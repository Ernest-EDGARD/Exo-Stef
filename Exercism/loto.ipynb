# %%
"""
  - loto boule de 1 à 49
  - 5 numéros
  - 1 complementaire
  
  ex : 45 2 6 7 54 ... 7   
"""
import random

loto = range(1, 49)

numero = random.sample(loto, 5)
print(f"voici les numéros du loto {numero}")

complementaire = random.randint(1,9)
print(f"voici le numéro complémentaire {complementaire}")
# Out:
# voici les numéros du loto [13, 8, 44, 15, 19]
# voici le numéro complémentaire 3

# %%
import random

nbrBoulesMax=49
nbrBoulesTirage=5

loto = range(1, nbrBoulesMax+1)
numeros_formates = ", ".join(map(str, numeros))

complementaire = random.randint(1,9)
print(f"voici le numéro complémentaire {numeros_formates} ... {complementaire}")
# Out:
# voici le numéro complémentaire 41, 19, 23, 30, 45 ... 7
